# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
gold_data=pd.read_csv('gld_price_data.csv')

# %%
gold_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
gold_data.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
gold_data.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
gold_data.shape
# Out:
# (2290, 6)

# %%
#info about the dataset
gold_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
#checking numm values

gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
#statistical measures
gold_data.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
correlation= gold_data.select_dtypes(include='number').corr()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(correlation,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':8},cmap='Blues')
# Out:
# <Axes: >

# %%
print(correlation['GLD'])
# Out:
# SPX        0.049345
# GLD        1.000000
# USO       -0.186360
# SLV        0.866632
# EUR/USD   -0.024375
# Name: GLD, dtype: float64

# %%
#distributon plot of gold
sns.distplot(gold_data['GLD'],color='green')
# Out:
# C:\Users\pbhar\AppData\Local\Temp\ipykernel_2732\2115273610.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(gold_data['GLD'],color='green')
# <Axes: xlabel='GLD', ylabel='Density'>

# %% [markdown]
# Splitting the features and Target
# =

# %%
X=gold_data.drop(['Date','GLD'],axis=1)
Y=gold_data['GLD']

# %%
print(X)
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
print(Y)
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %% [markdown]
# Splitting Training Data and Testing Data
# =

# %%
from sklearn.preprocessing import StandardScaler

X = gold_data.drop(['Date', 'GLD'], axis=1)
Y = gold_data['GLD']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

np.save('scaler_mean.npy',scaler.mean_)
np.save('scaler_scale.npy',scaler.scale_)

# %%
def predict(x,w,b):
    p=(np.dot(x,w)+b)
    return p

# %%
def compute_cost(x,y,w,b):
    m=x.shape[0]
    cost=0
    for i in range(m):
        #f_wb_i=w[i]*x[i]+b
        f_wb_i=np.dot(x[i],w)+b
        cost_sum=(f_wb_i-y[i])**2
        cost+=cost_sum
    total_cost=cost/(2*m)
    return total_cost

# %%
def compute_gradient(x,y,w,b):
    m,n=x.shape
    dj_dw=np.zeros((n,))
    dj_db=0.0
    for i in range(m):
        err=(np.dot(x[i],w)+b)-y[i]
        for j in range(n):
            dj_dw[j]=dj_dw[j]+err*x[i,j]
        dj_db=dj_db+err
    dj_dw/=m
    dj_db/=m
    return dj_db,dj_dw

# %%
def gradient_descent(x,y,w_in,b_in,cost_function,gradient_function,alpha,num_iters):
    w=w_in
    b=b_in
    j_history=[]
    
    for i in range(num_iters):
        dj_db,dj_dw=gradient_function(x,y,w,b)
        
        w-=alpha*dj_dw
        b-=alpha*dj_db
        if i<100000:
            j_history.append(cost_function(x,y,w,b))
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteration {i:4d}: Cost {j_history[-1]:8.2f}   ")
    return w,b,j_history

# %%
# Adjusted learning rate to prevent overflow
alpha = 0.001  # Reduced learning rate
num_iters = 7000

w_init = np.zeros(X_train.shape[1])
b_init = 0

w_final, b_final, j_hist = gradient_descent(X_train, Y_train.values, w_init, b_init, compute_cost, compute_gradient, alpha, num_iters) #.values is to compare pandas df into numpy array

print(f"w_final: {w_final}, b_final: {b_final}")
# Out:
# Iteration    0: Cost  7798.30
# Iteration  700: Cost  1955.02
# Iteration 1400: Cost   508.37
# Iteration 2100: Cost   149.84
# Iteration 2800: Cost    60.86
# Iteration 3500: Cost    38.73
# Iteration 4200: Cost    33.21
# Iteration 4900: Cost    31.83
# Iteration 5600: Cost    31.47
# Iteration 6300: Cost    31.38
# w_final: [ 3.41430955 -4.99912668 22.4043143  -1.21296045], b_final: 122.69787981675024

# %% [markdown]
# Cost Function Covergence
# =

# %%
import matplotlib.pyplot as plt

# Plot cost function over iterations
plt.figure(figsize=(10,6))
plt.plot(j_hist)
plt.title('Cost Function Convergence')
plt.xlabel('Iterations')
plt.ylabel('Cost (MSE)')
plt.grid(True)
plt.show()

# %%
y_pred=predict(X_test,w_final,b_final)

# %% [markdown]
# Actal values vs Predicted prices
# =

# %%
# Make predictions on the test set
Y_pred = np.dot(X_test, w_final) + b_final

# Plot Actual vs Predicted values
plt.figure(figsize=(10,6))
plt.scatter(Y_test, Y_pred, color='blue', alpha=0.6)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color='red', linestyle='--')
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.show()

# %% [markdown]
# Evalutation of model
# =

# %%
def mean_squared_error(Y_test,y_pred):
    return np.mean((Y_test-y_pred)**2)
mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error on Test Set: {mse}")
# Out:
# Mean Squared Error on Test Set: 70.57532866495525

# %%
error_score=metrics.r2_score(Y_test,y_pred)
print(f"R squared error: {error_score}")
# Out:
# R squared error: 0.8661935760370552

# %%
#saving the model parameters
np.save('weights.npy',w_final)
np.save('bias.npy',b_final)
